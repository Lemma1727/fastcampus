# %% [markdown]
# # 주제 : 흑백사진을 칼라로!
# --------------
# ## 실습 가이드
#     1. 데이터를 다운로드하여 Colab에 불러옵니다.
#     2. 필요한 라이브러리는 모두 코드로 작성되어 있습니다.
#     3. 코드는 위에서부터 아래로 순서대로 실행합니다.
#     4. 전체 문제 구성은 좌측 첫 번째 아이콘을 통해 확인할 수 있습니다.
#
# ## 데이터 소개
#     - 이번 주제의 데이터는 protrait 데이터로 유명한 PFCN dataset을 이용합니다.
#   ![PFCN dataset](https://www.researchgate.net/profile/Dawei_Li49/publication/334417334/figure/fig4/AS:832930272276492@1575597460956/Sample-images-from-the-PFCN-dataset.jpg)
#
#      위의 이미지는 다음과 같은 것을 보여줍니다.
#     - 800x600의 사람 portrait 이미지
#      - ?????.png
#     - 사람 영역에 대한 흑백 portrait 이미지
#      - ?????_matte.png
#     - pfcn_original
#      - 원본 800x600 이미지들
#     - pfcn_small
#      - colab용 100x75 이미지들
#
#
#
# - 데이터 출처:
#  - [PFCN dataset](https://1drv.ms/u/s!ApwdOxIIFBH19Ts5EuFd9gVJrKTo)
#  - [pfcn_small](https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing)
#
# ## 최종 목표
#
#     - 작게 줄인 PFCN 데이터를 이용
#     - 코렙에 구글 drive 연동
#     - 큰 사진을 작게 줄이기
#     - 이미지에 대한 오토인코더식 접근 방법
#     - 칼라 사진을 흑백 사진으로 만드는 모델 이해
#     - 흑백 사진을 칼라 사진으로 만드는 모델 이해
#
# - 출제자 : 손근영 강사
# ---

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %% [markdown]
# ## Step 1. 도입전 기본 처리

# %% [markdown]
# ### 문제 1. 구글 drive와 colab 연동하기

# %%
# https://onedrive.live.com/?authkey=%21ADkS4V32BUmspOg&cid=F5111408123B1D9C&id=F5111408123B1D9C%2115035&parId=F5111408123B1D9C%2115033&action=locate
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 문제 2. pfcn 데이터 살펴보기

# %%
# 데이터를 np array로 training에서 사람 이미지 한장을 불러오는 코드를 작성해주세요. (x로 변수 대입)
data_path = "/content/drive/MyDrive/[강의자료] 퀴즈처럼 풀면서 배우는 파이썬 딥러닝 300제+ 연습문제 패키치 Online/PART 1~3 강의자료/dataset"

import glob
import imageio

x = imageio.imread(data_path + "/training/00001.png")

# %% [markdown]
# ### 문제 3. x와 shape을 출력해보세요.

# %%
# 데이터의 크기를 shape 함수를 통해 출력해주세요.
x.shape
# Out:
# (800, 600, 3)

# %% [markdown]
# ### 문제 4. x를 plt를 통하여 출력하세요.

# %%
# x를 plt를 이용하여 출력하는 코드를 작성해보세요.
plt.imshow(x)

# %% [markdown]
# ### 문제 5. (800, 600)의 의미지는 colab에서 돌리기에 너무 큽니다. (100, 75)로 이미지를 줄여보세요

# %%
# x를 (800, 600, 3) -> (100, 75, 3)로 줄이고 plt에서 확인하는 코드를 작성하세요.
from skimage.transform import resize
x1 = resize(x, (100, 75))

# %% [markdown]
# ### 문제 6. pfcn_small.npz 데이터에서 학습, 테스트 데이터를 로드하세요.

# %%
# pfcn_small.npz에서 train_images, test_images를 np array로 로드하세요.

# !gdown --id 1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl

# %%
pfcn_small = np.load('/content/drive/MyDrive/[강의자료] 퀴즈처럼 풀면서 배우는 파이썬 딥러닝 300제+ 연습문제 패키치 Online/PART 1~3 강의자료/dataset/pfcn_small.npz')
train_images = pfcn_small["train_images"]
test_images = pfcn_small["test_images"]

# %% [markdown]
# ### 문제 7. train_images에서 0이 아닌 값들을 출력해보세요.

# %%
# 하나의 이미지에 대한 모든 0이 아닌 값을 출력하는 코드를 작성하세요.
print(train_images[0][train_images[0] != 0][:5])
# Out:
# [0.23627451 0.34803922 0.64705882 0.24509804 0.35686275]

# %% [markdown]
# ### 문제 8. train_images의 dtype을 출력해보세요.

# %%
# dtype을 이용하여 이미지의 np array type을 확인해보세요.
train_images.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 2. 전처리

# %% [markdown]
# ### 문제 9. train/test 이미지 데이터의 범위 확인

# %%
#  test_images shape과 dtype, 0이 아닌 숫자를 출력하는 코드를 작성하세요.
print(test_images.shape)
print(test_images.dtype)
print(test_images[test_images != 0][:5])
# Out:
# (300, 100, 75, 3)
# float64
# [0.50980392 0.64117647 0.64313725 0.51568627 0.64705882]

# %% [markdown]
# ### 문제 10. train/test 이미지 데이터의 최소/최대값을 출력

# %%
# train/test 전체 데이터에서 min, max를 출력하는 코드를 작성하세요.
print(min(train_images.reshape(-1)), max(train_images.reshape(-1)))
print(min(test_images.reshape(-1)), max(test_images.reshape(-1)))
# Out:
# 0.0 1.0
# 0.0 1.0

# %% [markdown]
# ### 문제 11. train_images와 test_images로 흑백인 train_gray_images, test_gray_images를 생성하세요.

# %%
# train_images와 test_images로 흑백인 train_gray_images, test_gray_images를 생성하세요.
from skimage.color import rgb2gray
train_gray_images = rgb2gray(train_images)
test_gray_images = rgb2gray(test_images)

# %% [markdown]
# ## Step 3. 시각화 방법

# %% [markdown]
# ### 문제 12. train_image의 이미지를 5장 획득하여 (5, 100, 75, 3)의 shape을 출력하세요.

# %%
# (배치, 100, 75, 3)인 train_images에서 (5, 100, 75, 3)을 획득하는 코드를 작성하세요.
train_images[:5].shape
# Out:
# (5, 100, 75, 3)

# %% [markdown]
# ### 문제 13. 획득한 5장의 의미지를 (100, 75 * 5, 3)의 shape으로 변경해보세요.

# %%
# np.hstack은 height 방향의 배열을 풀어서 width 방향으로 연결해줍니다.
# 해당 기능을 쓰면 (height, image_height, image_width, color)의 shape을 (image_height, image_width * height, color)으로 바꿔 줄 수 있습니다.
# 코드를 작성해보세요.
np.hstack(train_images[:5]).shape
# Out:
# (100, 375, 3)

# %% [markdown]
# ### 문제 14. (100, 375, 3)이 된 tensor를 plt로 출력해보세요.

# %%
# (28, 140, 3)의 이미지를 plt로 출력해보세요.
plt.imshow(np.hstack(train_images[:5]))

# %% [markdown]
# ### 문제 15. gray도 (100, 375)으로 plt로 출력해보세요.

# %%
# (28, 140, 1)의 이미지를 plt로 출력해보세요.
plt.imshow(np.hstack(train_gray_images[:5]), cmap="gray")

# %% [markdown]
# ## Step 4. 흑백 -> 칼라 모델링

# %% [markdown]
# ### 문제 16. 흑백 이미지를 칼라로 변환하는 모델을 작성하세요.

# %%
# input (100, 75, 1), output (100, 75, 3)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
from keras.layers import Conv2D, Dropout, Dense, Input, Flatten, BatchNormalization, MaxPool2D, Conv2DTranspose, Activation, concatenate
from keras.models import Model

def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x
def unet_color():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D((2,2))(c1)
    d1 = Dropout(0.3)(p1)

    c2 = conv2d_block(d1, 32)
    p2 = MaxPool2D((2,2))(c2)
    d2 = Dropout(0.3)(p2)

    c3 = conv2d_block(d2, 64)
    p3 = MaxPool2D((2,2))(c3)
    d3 = Dropout(0.3)(p3)

    c4 = conv2d_block(d3, 128)
    p4 = MaxPool2D((2,2))(c4)
    d4 = Dropout(0.3)(p4)

    latent = conv2d_block(d4 , 256)

    u1 = Conv2DTranspose(128, 2, 2, output_padding=(0, 1))(latent)
    u1 = concatenate((u1, c4))
    u1 = Dropout(0.3)(u1)
    c5 = conv2d_block(u1, 128)

    u2 = Conv2DTranspose(64, 2, 2, output_padding=(1, 0))(c5)
    u2 = concatenate((u2, c3))
    u2 = Dropout(0.3)(u2)
    c6 = conv2d_block(u2, 64)

    u3 = Conv2DTranspose(32, 2, 2, output_padding=(0, 1))(c6)
    u3 = concatenate((u3, c2))
    u3 = Dropout(0.3)(u3)
    c7 = conv2d_block(u3, 32)

    u4 = Conv2DTranspose(16, 2, 2, output_padding=(0, 1))(c7)
    u4 = concatenate((u4, c1))
    u4 = Dropout(0.3)(u4)
    outputs = conv2d_block(u4, 16)

    outputs = Conv2D(3, 1, activation="sigmoid")(outputs)

    return Model(inputs, outputs)

unet_color().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 75, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 100, 75, 16)  160         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 100, 75, 16)  64         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 100, 75, 16)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 100, 75, 16)  2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 100, 75, 16)  64         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 100, 75, 16)  0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 50, 37, 16)   0           ['activation_1[0][0]']
#
#  dropout (Dropout)              (None, 50, 37, 16)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 50, 37, 32)   4640        ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 50, 37, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 50, 37, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 50, 37, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 50, 37, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 50, 37, 32)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 18, 32)  0           ['activation_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 25, 18, 32)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 25, 18, 64)   18496       ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 25, 18, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 25, 18, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 25, 18, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 18, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 25, 18, 64)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 9, 64)   0           ['activation_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 12, 9, 64)    0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 9, 128)   73856       ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 12, 9, 128)  512         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 12, 9, 128)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 9, 128)   147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 12, 9, 128)  512         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 12, 9, 128)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 4, 128)   0           ['activation_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 6, 4, 128)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 4, 256)    295168      ['dropout_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 6, 4, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 6, 4, 256)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 4, 256)    590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 6, 4, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 6, 4, 256)    0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 12, 9, 128)  131200      ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 12, 9, 256)   0           ['conv2d_transpose[0][0]',
#                                                                   'activation_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 12, 9, 256)   0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 9, 128)   295040      ['dropout_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 9, 128)  512         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 9, 128)   147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 9, 128)  512         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 25, 18, 64)  32832       ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 25, 18, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 25, 18, 128)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 18, 64)   73792       ['dropout_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 18, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 18, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 18, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 50, 37, 32)  8224        ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 50, 37, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 50, 37, 64)   0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 50, 37, 32)   18464       ['dropout_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 50, 37, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 50, 37, 32)   9248        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 50, 37, 32)  128         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 100, 75, 16)  2064       ['activation_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 100, 75, 32)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'activation_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 100, 75, 32)  0           ['concatenate_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 100, 75, 16)  4624        ['dropout_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 100, 75, 16)  64         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 100, 75, 16)  2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 100, 75, 16)  64         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 100, 75, 3)   51          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 1,946,739
# Trainable params: 1,943,795
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# ### 문제 17. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# unet_color() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
model = unet_color()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 100, 75, 1)  0           []
#                                 ]
#
#  conv2d_19 (Conv2D)             (None, 100, 75, 16)  160         ['input_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 100, 75, 16)  64         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 100, 75, 16)  2320        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 100, 75, 16)  64         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_19[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 50, 37, 16)  0           ['activation_19[0][0]']
#
#  dropout_8 (Dropout)            (None, 50, 37, 16)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 50, 37, 32)   4640        ['dropout_8[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 50, 37, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 50, 37, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 50, 37, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 25, 18, 32)  0           ['activation_21[0][0]']
#
#  dropout_9 (Dropout)            (None, 25, 18, 32)   0           ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 18, 64)   18496       ['dropout_9[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 18, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 18, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 25, 18, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 9, 64)   0           ['activation_23[0][0]']
#
#  dropout_10 (Dropout)           (None, 12, 9, 64)    0           ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 9, 128)   73856       ['dropout_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 12, 9, 128)  512         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 9, 128)   147584      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 12, 9, 128)  512         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 4, 128)   0           ['activation_25[0][0]']
#
#  dropout_11 (Dropout)           (None, 6, 4, 128)    0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 6, 4, 256)    295168      ['dropout_11[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 6, 4, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 6, 4, 256)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 6, 4, 256)    590080      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 6, 4, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 6, 4, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 12, 9, 128)  131200      ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 12, 9, 256)   0           ['conv2d_transpose_4[0][0]',
#                                                                   'activation_25[0][0]']
#
#  dropout_12 (Dropout)           (None, 12, 9, 256)   0           ['concatenate_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 9, 128)   295040      ['dropout_12[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 12, 9, 128)  512         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 9, 128)   147584      ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 12, 9, 128)  512         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 25, 18, 64)  32832       ['activation_29[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 25, 18, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_23[0][0]']
#
#  dropout_13 (Dropout)           (None, 25, 18, 128)  0           ['concatenate_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 25, 18, 64)   73792       ['dropout_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 25, 18, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 25, 18, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 25, 18, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 50, 37, 32)  8224        ['activation_31[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 50, 37, 64)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'activation_21[0][0]']
#
#  dropout_14 (Dropout)           (None, 50, 37, 64)   0           ['concatenate_6[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 50, 37, 32)   18464       ['dropout_14[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 50, 37, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 50, 37, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 50, 37, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 100, 75, 16)  2064       ['activation_33[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 100, 75, 32)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'activation_19[0][0]']
#
#  dropout_15 (Dropout)           (None, 100, 75, 32)  0           ['concatenate_7[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 100, 75, 16)  4624        ['dropout_15[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 100, 75, 16)  64         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 100, 75, 16)  2320        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 100, 75, 16)  64         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 100, 75, 3)   51          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 1,946,739
# Trainable params: 1,943,795
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# ### 문제 18. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mse, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["accuracy"]
)

# %% [markdown]
# ### 문제 19. 만든 모델에 train_gray_images, train_images를 학습시켜 보세요.

# %%
# train_gray_images 학습시키고 5 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist = model.fit(train_gray_images, train_images, batch_size=64, epochs=5, verbose=True, validation_data=(test_gray_images, test_images))
# Out:
# Epoch 1/5
# 27/27 [==============================] - 22s 285ms/step - loss: 0.0433 - accuracy: 0.3543 - val_loss: 0.0670 - val_accuracy: 0.3663
# Epoch 2/5
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0187 - accuracy: 0.4856 - val_loss: 0.0692 - val_accuracy: 0.6892
# Epoch 3/5
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0136 - accuracy: 0.5643 - val_loss: 0.0685 - val_accuracy: 0.6892
# Epoch 4/5
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0114 - accuracy: 0.6060 - val_loss: 0.0672 - val_accuracy: 0.6883
# Epoch 5/5
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0102 - accuracy: 0.6118 - val_loss: 0.0656 - val_accuracy: 0.6846

# %% [markdown]
# ### 문제 20. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history["accuracy"], label="accuracy")
plt.plot(hist.history["val_accuracy"], label="val_accuracy")
plt.plot(hist.history["loss"], label="loss")
plt.plot(hist.history["val_loss"], label="val_loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 5. 칼라 모델 결과 확인

# %% [markdown]
# ### 문제 21. 완성된 모델에서 test_gray_images를 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 test_gray_images 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model.predict(test_gray_images[0:1])

# %%
test_images[0].shape
# Out:
# (100, 75, 3)

# %% [markdown]
# ### 문제 22. res와 test_images[1]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# res와 test_images[1]를 width 방향으로 결합하여 (100, 75 * 3, 3) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
plt.imshow(np.concatenate((res.reshape(100, 75, 3), test_images[0]), axis=1))
plt.show()

# %% [markdown]
# ### 문제 23. 5장의 test_gray_images를 모델에 넣은 뒤 결과를 문제 29 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 29번과 같은 방식으로 비교하는 코드를 작성하세요.
res5 = model.predict(test_gray_images[:5])
res5 = np.hstack(res5)
plt.imshow(np.concatenate((res5.reshape(100, -1, 3), test_images[:5].transpose(1, 0, 2, 3).reshape(100, -1, 3))))
plt.show()

# %% [markdown]
# ## Step 6. lab 칼라 모델링

# %% [markdown]
# ### 문제 24. rgb 칼라를 lab 칼라로 바꿔보세요. (위의 color 모델이 잘못된 것은 아님)

# %%
# rgb2lab을 이용하여 rgb 칼라를 lab 칼라로 바꾸는 코드를 작성하세요.
from skimage.color import rgb2lab
train_lab_images = np.array([rgb2lab(img) for img in train_images])
test_lab_images = np.array([rgb2lab(img) for img in test_images])

# %%
train_lab_images.shape
# Out:
# (1700, 100, 75, 3)

# %% [markdown]
# ### 문제 25. lab 칼라 이미지를 채널별로 최대, 최소 값을 출력해보세요.

# %%
# lab 칼라 이미지를 채널별로 최대, 최소 값을 출력하는 코드를 작성하세요.
print(train_lab_images[..., 0].max(), train_lab_images[..., 0].min())
print(train_lab_images[..., 1].max(), train_lab_images[..., 1].min())
print(train_lab_images[..., 2].max(), train_lab_images[..., 2].min())
# Out:
# 100.0 0.0
# 86.20773183914271 -78.53736435567544
# 93.80664030542576 -91.97308466277427

# %% [markdown]
# ### 문제 26. lab 칼라는 채널별 최대값을 [0-100, +-128, +-128]로 가지고 있습니다. 0-1 노말라이즈 하세요.

# %%
# lab 칼라를 노말라이즈 하는 코드를 작성하세요.
train_lab_images = train_lab_images + [0, 128, 128]
train_lab_images = train_lab_images / [100.0, 255.0, 255.0]

test_lab_images = test_lab_images + [0, 128, 128]
test_lab_images = test_lab_images / [100.0, 255.0, 255.0]

print(train_lab_images[..., 0].max(), train_lab_images[..., 0].min())
print(train_lab_images[..., 1].max(), train_lab_images[..., 1].min())
print(train_lab_images[..., 2].max(), train_lab_images[..., 2].min())
# Out:
# 1.0 0.0
# 0.8400303209378145 0.19397112017382181
# 0.8698299619820618 0.141282020930297

# %% [markdown]
# ### 문제 27. lab 칼라의 이미지 하나를 고르고 첫번째 채널을 plt으로 출력해보세요.

# %%
# lab 칼라 이미지의 첫번째 채널을 plt로 출력하는 코드를 작성하세요.
plt.imshow(train_lab_images[7][..., 0])
plt.show()

# %% [markdown]
# ### 문제 28. lab 칼라 첫번째 채널로 나머지 2채널을 예측하는 모델을 작성하세요.

# %%
# input (100, 75, 1), output (100, 75, 2)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def unet_lab():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D((2,2))(c1)
    d1 = Dropout(0.3)(p1)

    c2 = conv2d_block(d1, 32)
    p2 = MaxPool2D((2,2))(c2)
    d2 = Dropout(0.3)(p2)

    c3 = conv2d_block(d2, 64)
    p3 = MaxPool2D((2,2))(c3)
    d3 = Dropout(0.3)(p3)

    c4 = conv2d_block(d3, 128)
    p4 = MaxPool2D((2,2))(c4)
    d4 = Dropout(0.3)(p4)

    latent = conv2d_block(d4 , 256)

    u1 = Conv2DTranspose(128, 2, 2, output_padding=(0, 1))(latent)
    u1 = concatenate((u1, c4))
    u1 = Dropout(0.3)(u1)
    c5 = conv2d_block(u1, 128)

    u2 = Conv2DTranspose(64, 2, 2, output_padding=(1, 0))(c5)
    u2 = concatenate((u2, c3))
    u2 = Dropout(0.3)(u2)
    c6 = conv2d_block(u2, 64)

    u3 = Conv2DTranspose(32, 2, 2, output_padding=(0, 1))(c6)
    u3 = concatenate((u3, c2))
    u3 = Dropout(0.3)(u3)
    c7 = conv2d_block(u3, 32)

    u4 = Conv2DTranspose(16, 2, 2, output_padding=(0, 1))(c7)
    u4 = concatenate((u4, c1))
    u4 = Dropout(0.3)(u4)
    outputs = conv2d_block(u4, 16)

    outputs = Conv2D(2, 1, activation="sigmoid")(outputs)

    return Model(inputs, outputs)

# %% [markdown]
# ### 문제 29. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# unet_lab() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
unet_lab().summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100, 75, 1)  0           []
#                                 ]
#
#  conv2d_38 (Conv2D)             (None, 100, 75, 16)  160         ['input_3[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 100, 75, 16)  64         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 100, 75, 16)  2320        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 100, 75, 16)  64         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_37[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 50, 37, 16)  0           ['activation_37[0][0]']
#
#  dropout_16 (Dropout)           (None, 50, 37, 16)   0           ['max_pooling2d_8[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 50, 37, 32)   4640        ['dropout_16[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 50, 37, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 50, 37, 32)   9248        ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 50, 37, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_39[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 18, 32)  0           ['activation_39[0][0]']
#
#  dropout_17 (Dropout)           (None, 25, 18, 32)   0           ['max_pooling2d_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 25, 18, 64)   18496       ['dropout_17[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 25, 18, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 25, 18, 64)   36928       ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 25, 18, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_41[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 12, 9, 64)   0           ['activation_41[0][0]']
#  )
#
#  dropout_18 (Dropout)           (None, 12, 9, 64)    0           ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 9, 128)   73856       ['dropout_18[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 12, 9, 128)  512         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 9, 128)   147584      ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 12, 9, 128)  512         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_43[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 6, 4, 128)   0           ['activation_43[0][0]']
#  )
#
#  dropout_19 (Dropout)           (None, 6, 4, 128)    0           ['max_pooling2d_11[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 6, 4, 256)    295168      ['dropout_19[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 6, 4, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 6, 4, 256)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 6, 4, 256)    590080      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 6, 4, 256)   1024        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 6, 4, 256)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 12, 9, 128)  131200      ['activation_45[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 12, 9, 256)   0           ['conv2d_transpose_8[0][0]',
#                                                                   'activation_43[0][0]']
#
#  dropout_20 (Dropout)           (None, 12, 9, 256)   0           ['concatenate_8[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 9, 128)   295040      ['dropout_20[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 12, 9, 128)  512         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 9, 128)   147584      ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 12, 9, 128)  512         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 12, 9, 128)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 25, 18, 64)  32832       ['activation_47[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 25, 18, 128)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'activation_41[0][0]']
#
#  dropout_21 (Dropout)           (None, 25, 18, 128)  0           ['concatenate_9[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 25, 18, 64)   73792       ['dropout_21[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 25, 18, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 25, 18, 64)   36928       ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 25, 18, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 25, 18, 64)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 50, 37, 32)  8224        ['activation_49[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 50, 37, 64)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'activation_39[0][0]']
#
#  dropout_22 (Dropout)           (None, 50, 37, 64)   0           ['concatenate_10[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 50, 37, 32)   18464       ['dropout_22[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 50, 37, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 50, 37, 32)   9248        ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 50, 37, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 50, 37, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 100, 75, 16)  2064       ['activation_51[0][0]']
#  nspose)
#
#  concatenate_11 (Concatenate)   (None, 100, 75, 32)  0           ['conv2d_transpose_11[0][0]',
#                                                                   'activation_37[0][0]']
#
#  dropout_23 (Dropout)           (None, 100, 75, 32)  0           ['concatenate_11[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 100, 75, 16)  4624        ['dropout_23[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 100, 75, 16)  64         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 100, 75, 16)  2320        ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 100, 75, 16)  64         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 100, 75, 16)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 100, 75, 2)   34          ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 1,946,722
# Trainable params: 1,943,778
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# ### 문제 30. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mae, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model2 = unet_lab()
model2.compile(
    loss="mse",
    optimizer="adam",
    metrics=["accuracy"]
)

# %% [markdown]
# ### 문제 31. 만든 모델에 train_lab_images[...,0], train_lab_images[...,1:]를 학습시켜 보세요.

# %%
# train_lab_images[...,0], 학습시키고 50 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist2 = model2.fit(
    train_lab_images[..., 0:1], train_lab_images[..., 1:],
    batch_size=64,
    epochs=50,
    verbose=True,
    validation_data=(test_lab_images[..., 0:1], test_lab_images[..., 1:])
    )
# Out:
# Epoch 1/50
# 27/27 [==============================] - 9s 227ms/step - loss: 0.0121 - accuracy: 0.5246 - val_loss: 0.1330 - val_accuracy: 0.4876
# Epoch 2/50
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0031 - accuracy: 0.5678 - val_loss: 0.0782 - val_accuracy: 0.4615
# Epoch 3/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0029 - accuracy: 0.5912 - val_loss: 0.0029 - val_accuracy: 0.5663
# Epoch 4/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0028 - accuracy: 0.5863 - val_loss: 0.0027 - val_accuracy: 0.5923
# Epoch 5/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0027 - accuracy: 0.5911 - val_loss: 0.0029 - val_accuracy: 0.5817
# Epoch 6/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0027 - accuracy: 0.5859 - val_loss: 0.0028 - val_accuracy: 0.5901
# Epoch 7/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0026 - accuracy: 0.5943 - val_loss: 0.0027 - val_accuracy: 0.5929
# Epoch 8/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0026 - accuracy: 0.5991 - val_loss: 0.0025 - val_accuracy: 0.6087
# Epoch 9/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0026 - accuracy: 0.5967 - val_loss: 0.0025 - val_accuracy: 0.6105
# Epoch 10/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0026 - accuracy: 0.5964 - val_loss: 0.0025 - val_accuracy: 0.6178
# Epoch 11/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0025 - accuracy: 0.6030 - val_loss: 0.0026 - val_accuracy: 0.6212
# Epoch 12/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0025 - accuracy: 0.6039 - val_loss: 0.0029 - val_accuracy: 0.5772
# Epoch 13/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0025 - accuracy: 0.6025 - val_loss: 0.0031 - val_accuracy: 0.5904
# Epoch 14/50
# 27/27 [==============================] - 5s 203ms/step - loss: 0.0025 - accuracy: 0.6078 - val_loss: 0.0030 - val_accuracy: 0.5349
# Epoch 15/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0025 - accuracy: 0.6092 - val_loss: 0.0027 - val_accuracy: 0.5856
# Epoch 16/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0025 - accuracy: 0.6118 - val_loss: 0.0028 - val_accuracy: 0.5845
# Epoch 17/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0025 - accuracy: 0.6114 - val_loss: 0.0025 - val_accuracy: 0.6142
# Epoch 18/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0024 - accuracy: 0.6121 - val_loss: 0.0030 - val_accuracy: 0.5731
# Epoch 19/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0024 - accuracy: 0.6125 - val_loss: 0.0024 - val_accuracy: 0.6148
# Epoch 20/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0024 - accuracy: 0.6143 - val_loss: 0.0025 - val_accuracy: 0.6122
# Epoch 21/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0024 - accuracy: 0.6163 - val_loss: 0.0023 - val_accuracy: 0.6196
# Epoch 22/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0024 - accuracy: 0.6154 - val_loss: 0.0024 - val_accuracy: 0.6185
# Epoch 23/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0024 - accuracy: 0.6239 - val_loss: 0.0023 - val_accuracy: 0.6150
# Epoch 24/50
# 27/27 [==============================] - 5s 203ms/step - loss: 0.0023 - accuracy: 0.6208 - val_loss: 0.0023 - val_accuracy: 0.6235
# Epoch 25/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6245 - val_loss: 0.0023 - val_accuracy: 0.6265
# Epoch 26/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6276 - val_loss: 0.0023 - val_accuracy: 0.6276
# Epoch 27/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6207 - val_loss: 0.0022 - val_accuracy: 0.6155
# Epoch 28/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0023 - accuracy: 0.6231 - val_loss: 0.0022 - val_accuracy: 0.6303
# Epoch 29/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6321 - val_loss: 0.0022 - val_accuracy: 0.6287
# Epoch 30/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6313 - val_loss: 0.0023 - val_accuracy: 0.6277
# Epoch 31/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0022 - accuracy: 0.6365 - val_loss: 0.0022 - val_accuracy: 0.6309
# Epoch 32/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0023 - accuracy: 0.6320 - val_loss: 0.0023 - val_accuracy: 0.6290
# Epoch 33/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0022 - accuracy: 0.6389 - val_loss: 0.0022 - val_accuracy: 0.6347
# Epoch 34/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0022 - accuracy: 0.6369 - val_loss: 0.0022 - val_accuracy: 0.6397
# Epoch 35/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0022 - accuracy: 0.6439 - val_loss: 0.0023 - val_accuracy: 0.6400
# Epoch 36/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0022 - accuracy: 0.6446 - val_loss: 0.0023 - val_accuracy: 0.6402
# Epoch 37/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0022 - accuracy: 0.6463 - val_loss: 0.0023 - val_accuracy: 0.6470
# Epoch 38/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0021 - accuracy: 0.6483 - val_loss: 0.0022 - val_accuracy: 0.6421
# Epoch 39/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0021 - accuracy: 0.6521 - val_loss: 0.0024 - val_accuracy: 0.6443
# Epoch 40/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0021 - accuracy: 0.6492 - val_loss: 0.0022 - val_accuracy: 0.6476
# Epoch 41/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0021 - accuracy: 0.6535 - val_loss: 0.0024 - val_accuracy: 0.6349
# Epoch 42/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0021 - accuracy: 0.6489 - val_loss: 0.0023 - val_accuracy: 0.6449
# Epoch 43/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0020 - accuracy: 0.6545 - val_loss: 0.0022 - val_accuracy: 0.6446
# Epoch 44/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0020 - accuracy: 0.6570 - val_loss: 0.0022 - val_accuracy: 0.6496
# Epoch 45/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0020 - accuracy: 0.6591 - val_loss: 0.0023 - val_accuracy: 0.6416
# Epoch 46/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0020 - accuracy: 0.6600 - val_loss: 0.0022 - val_accuracy: 0.6485
# Epoch 47/50
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0019 - accuracy: 0.6609 - val_loss: 0.0023 - val_accuracy: 0.6519
# Epoch 48/50
# 27/27 [==============================] - 5s 201ms/step - loss: 0.0019 - accuracy: 0.6614 - val_loss: 0.0023 - val_accuracy: 0.6497
# Epoch 49/50
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0019 - accuracy: 0.6639 - val_loss: 0.0024 - val_accuracy: 0.6425
# Epoch 50/50
# 27/27 [==============================] - 6s 214ms/step - loss: 0.0019 - accuracy: 0.6646 - val_loss: 0.0024 - val_accuracy: 0.6440

# %% [markdown]
# ### 문제 32. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist2.history["accuracy"], label="accuracy")
plt.plot(hist2.history["val_accuracy"], label="val_accuracy")
plt.plot(hist2.history["loss"], label="loss")
plt.plot(hist2.history["val_loss"], label="val_loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 7. lab 칼라 모델 결과 확인

# %% [markdown]
# ### 문제 33. 완성된 모델에서 흑백이미지 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 흑백이미지 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model2.predict(test_lab_images[1:2][..., 0:1])

# %%
res.shape
# Out:
# (1, 100, 75, 2)

# %% [markdown]
# ### 문제 34. res와 test_lab_images[...,1:]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# res와 test_images[1]를 width 방향으로 결합하여 (100, 75 * 3, 3) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
from skimage import color
def l2rgb(l):
    pred_ab = model2.predict(np.expand_dims(l, 0))
    pred_img = np.zeros((100, 75, 3))

    pred_img[:, :, 0] = l.reshape((100, 75))
    pred_img[:, :, 1:] = pred_ab[0]

    pred_lab = (pred_img * [100, 255, 255]) - [0, 128, 128]
    rgb_img = color.lab2rgb(pred_lab)
    return rgb_img

plt.imshow(l2rgb(test_lab_images[5][..., 0]))

# %% [markdown]
# ### 문제 35. 5장의 test_lab_images를 모델에 넣은 뒤 결과를 문제 29 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 29번과 같은 방식으로 비교하는 코드를 작성하세요.
five = np.array([l2rgb(img) for img in test_lab_images[:5][..., 0]])
five = np.hstack(five)
plt.imshow(np.concatenate((five.reshape(100, -1, 3), test_images[:5].transpose(1, 0, 2, 3).reshape(100, -1, 3))))
plt.show()

# %% [markdown]
# ## Step 8. 모델 저장 및 로드, 다운

# %% [markdown]
# ### 문제 36. 모델을 저장하세요.

# %%
# 모델을 저장하는 코드를 작성하세요.
model2.save("./lecture006.h5")

# %% [markdown]
# ### 문제 37. 모델 파일을 새로운 모델에 로드하세요.

# %%
# 모델을 로드하는 코드를 작성하세요.
new_model = tf.keras.models.load_model("./lecture006.h5")

# %% [markdown]
# ### 문제 38. 로드한 모델을 test 데이터로 평가해보세요.

# %%
# 로드한 모델을 test 데이터로 평가해보세요.
new_model.evaluate(test_lab_images[..., 0], test_lab_images[..., 1:], verbose=True)

# %% [markdown]
# ### 문제 39. 모델을 내 컴퓨터에 저장해보세요

# %%
# 모델을 내 컴퓨터에 저장해보세요.
from google.colab import files
files.download("./lecture006.h5")
